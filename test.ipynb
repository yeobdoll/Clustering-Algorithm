# %%
import os
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
cd /content/drive/MyDrive/Colab_Notebooks/Github
# Out:
# /content/drive/MyDrive/Colab_Notebooks/Github

# %%
cd basic-1/
# Out:
# /content/drive/MyDrive/Colab_Notebooks/Github/basic-1

# %%
# !git config --global user.email 'jsysu2846@naver.com'
# !git config --global user.name 'yeobdoll'

# %%
# !git commit -m "test01"
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git push
# Out:
# fatal: not a git repository (or any of the parent directories): .git
